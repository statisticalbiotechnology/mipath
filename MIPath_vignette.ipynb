# %% [markdown]
# # MIPath Vignette
#
# ## Package installation
#
# Install MIPath with
#
# `pip install mipathway`
#
# ## Usage example
#
# Here we will give an example on how to run a standard pathway analysis with MIPath.
#
# First, we will load the libraries. Here we will also use **scanpy** to download and process a single cell dataset. You can install **scanpy** with `pip install scanpy`

# %%
import mipath
import scanpy as sc

# %% [markdown]
# We will use a dataset of a *hematopoietic cell lineage*, taken from the paper:
#
# Ranzoni AM, Tangherloni A, Berest I, Riva SG, Myers B et al. (2021) Integrative Single-Cell RNA-Seq and ATAC-Seq Analysis of Human Developmental Hematopoiesis
#
# It is present in the EBI Single Cell Expression Atlas, under the id E-MTAB-9067. We use **scanpy** to download the dataset, and preprocess it.

# %%
dataset_id = 'E-MTAB-9067'

adata = sc.datasets.ebi_expression_atlas(dataset_id)
     
# Basic filtering
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# Library size correction
sc.pp.normalize_total(adata, target_sum=1e4)

# Logarithmize the data
sc.pp.log1p(adata)

# %% [markdown]
# Next, we extract the two dataframes we need for the analysis, one with the gene expression information, and a second with phenotype information for each cell.

# %%
metadata = adata.obs
data = adata.to_df()

# %% [markdown]
# The dataframe with gene expression looks like this

# %%
data.head(10)
# Out:
#             ENSG00000000003  ENSG00000000419  ENSG00000000457  \
# ERR4147602         0.000000         0.123530         0.000000
# ERR4147603         0.000000         0.000000         0.000000
# ERR4147604         0.000000         1.075944         0.000000
# ERR4147605         0.000000         0.435912         0.094710
# ERR4147606         0.000000         0.693898         0.000000
# ERR4147607         0.000000         0.000000         0.000000
# ERR4147608         0.104638         0.036110         0.000000
# ERR4147609         0.000000         0.000000         0.000000
# ERR4147610         0.000000         0.023072         0.000000
# ERR4147611         0.000000         0.101359         0.101359
#
#             ENSG00000000460  ENSG00000000938  ENSG00000000971  \
# ERR4147602         0.000000              0.0         0.000000
# ERR4147603         0.000000              0.0         0.000000
# ERR4147604         0.000000              0.0         0.000000
# ERR4147605         0.048476              0.0         0.138901
# ERR4147606         0.000000              0.0         2.029455
# ERR4147607         0.000000              0.0         0.031404
# ERR4147608         0.043839              0.0         0.000000
# ERR4147609         0.000000              0.0         0.476586
# ERR4147610         0.000000              0.0         0.000000
# ERR4147611         0.913659              0.0         0.000000
#
#             ENSG00000001036  ENSG00000001084  ENSG00000001167  \
# ERR4147602         0.000000         0.000000              0.0
# ERR4147603         0.000000         0.000000              0.0
# ERR4147604         0.000000         0.096876              0.0
# ERR4147605         0.334586         0.048476              0.0
# ERR4147606         0.000000         0.000000              0.0
# ERR4147607         0.000000         0.027872              0.0
# ERR4147608         0.000000         0.036110              0.0
# ERR4147609         0.000000         0.000000              0.0
# ERR4147610         0.000000         0.398879              0.0
# ERR4147611         0.000000         0.000000              0.0
#
#             ENSG00000001460  ...  ENSG00000289685  ENSG00000289690  \
# ERR4147602         0.000000  ...         0.123530              0.0
# ERR4147603         0.000000  ...         0.204019              0.0
# ERR4147604         0.185191  ...         1.763158              0.0
# ERR4147605         0.181222  ...         0.278324              0.0
# ERR4147606         0.000000  ...         0.000000              0.0
# ERR4147607         0.081388  ...         0.000000              0.0
# ERR4147608         0.000000  ...         0.036110              0.0
# ERR4147609         0.000000  ...         0.000000              0.0
# ERR4147610         0.000000  ...         0.000000              0.0
# ERR4147611         0.000000  ...         0.776297              0.0
#
#             ENSG00000289692  ENSG00000289694  ENSG00000289695  \
# ERR4147602              0.0         0.000000              0.0
# ERR4147603              0.0         0.000000              0.0
# ERR4147604              0.0         0.618255              0.0
# ERR4147605              0.0         0.000000              0.0
# ERR4147606              0.0         0.000000              0.0
# ERR4147607              0.0         0.000000              0.0
# ERR4147608              0.0         0.000000              0.0
# ERR4147609              0.0         0.000000              0.0
# ERR4147610              0.0         0.000000              0.0
# ERR4147611              0.0         0.642046              0.0
#
#             ENSG00000289697  ENSG00000289700  ENSG00000289701  \
# ERR4147602              0.0              0.0              0.0
# ERR4147603              0.0              0.0              0.0
# ERR4147604              0.0              0.0              0.0
# ERR4147605              0.0              0.0              0.0
# ERR4147606              0.0              0.0              0.0
# ERR4147607              0.0              0.0              0.0
# ERR4147608              0.0              0.0              0.0
# ERR4147609              0.0              0.0              0.0
# ERR4147610              0.0              0.0              0.0
# ERR4147611              0.0              0.0              0.0
#
#             ENSG00000289716  ENSG00000289718
# ERR4147602              0.0              0.0
# ERR4147603              0.0              0.0
# ERR4147604              0.0              0.0
# ERR4147605              0.0              0.0
# ERR4147606              0.0              0.0
# ERR4147607              0.0              0.0
# ERR4147608              0.0              0.0
# ERR4147609              0.0              0.0
# ERR4147610              0.0              0.0
# ERR4147611              0.0              0.0
#
# [10 rows x 32777 columns]

# %% [markdown]
# And the one with phenotype information

# %%
metadata.head(10)
# Out:
#            Sample Characteristic[organism]  \
# ERR4147602                    Homo sapiens
# ERR4147603                    Homo sapiens
# ERR4147604                    Homo sapiens
# ERR4147605                    Homo sapiens
# ERR4147606                    Homo sapiens
# ERR4147607                    Homo sapiens
# ERR4147608                    Homo sapiens
# ERR4147609                    Homo sapiens
# ERR4147610                    Homo sapiens
# ERR4147611                    Homo sapiens
#
#             Sample Characteristic Ontology Term[organism]  \
# ERR4147602  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147603  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147604  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147605  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147606  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147607  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147608  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147609  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147610  http://purl.obolibrary.org/obo/NCBITaxon_9606
# ERR4147611  http://purl.obolibrary.org/obo/NCBITaxon_9606
#
#            Sample Characteristic[individual]  \
# ERR4147602                           Sample2
# ERR4147603                           Sample2
# ERR4147604                           Sample2
# ERR4147605                           Sample2
# ERR4147606                           Sample2
# ERR4147607                           Sample2
# ERR4147608                           Sample2
# ERR4147609                           Sample2
# ERR4147610                           Sample2
# ERR4147611                           Sample2
#
#             Sample Characteristic Ontology Term[individual]  \
# ERR4147602                                              NaN
# ERR4147603                                              NaN
# ERR4147604                                              NaN
# ERR4147605                                              NaN
# ERR4147606                                              NaN
# ERR4147607                                              NaN
# ERR4147608                                              NaN
# ERR4147609                                              NaN
# ERR4147610                                              NaN
# ERR4147611                                              NaN
#
#            Sample Characteristic[developmental stage]  \
# ERR4147602                       late embryonic stage
# ERR4147603                       late embryonic stage
# ERR4147604                       late embryonic stage
# ERR4147605                       late embryonic stage
# ERR4147606                       late embryonic stage
# ERR4147607                       late embryonic stage
# ERR4147608                       late embryonic stage
# ERR4147609                       late embryonic stage
# ERR4147610                       late embryonic stage
# ERR4147611                       late embryonic stage
#
#            Sample Characteristic Ontology Term[developmental stage]  \
# ERR4147602      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147603      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147604      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147605      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147606      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147607      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147608      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147609      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147610      http://purl.obolibrary.org/obo/UBERON_0007220
# ERR4147611      http://purl.obolibrary.org/obo/UBERON_0007220
#
#            Sample Characteristic[age]  \
# ERR4147602                    17 week
# ERR4147603                    17 week
# ERR4147604                    17 week
# ERR4147605                    17 week
# ERR4147606                    17 week
# ERR4147607                    17 week
# ERR4147608                    17 week
# ERR4147609                    17 week
# ERR4147610                    17 week
# ERR4147611                    17 week
#
#             Sample Characteristic Ontology Term[age]  \
# ERR4147602                                       NaN
# ERR4147603                                       NaN
# ERR4147604                                       NaN
# ERR4147605                                       NaN
# ERR4147606                                       NaN
# ERR4147607                                       NaN
# ERR4147608                                       NaN
# ERR4147609                                       NaN
# ERR4147610                                       NaN
# ERR4147611                                       NaN
#
#            Sample Characteristic[sex]  \
# ERR4147602                     female
# ERR4147603                     female
# ERR4147604                     female
# ERR4147605                     female
# ERR4147606                     female
# ERR4147607                     female
# ERR4147608                     female
# ERR4147609                     female
# ERR4147610                     female
# ERR4147611                     female
#
#                Sample Characteristic Ontology Term[sex]  ...  \
# ERR4147602  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147603  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147604  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147605  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147606  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147607  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147608  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147609  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147610  http://purl.obolibrary.org/obo/PATO_0000383  ...
# ERR4147611  http://purl.obolibrary.org/obo/PATO_0000383  ...
#
#            Factor Value Ontology Term[single cell identifier]  \
# ERR4147602                                                NaN
# ERR4147603                                                NaN
# ERR4147604                                                NaN
# ERR4147605                                                NaN
# ERR4147606                                                NaN
# ERR4147607                                                NaN
# ERR4147608                                                NaN
# ERR4147609                                                NaN
# ERR4147610                                                NaN
# ERR4147611                                                NaN
#
#            Factor Value[organism part]  \
# ERR4147602                 bone marrow
# ERR4147603                 bone marrow
# ERR4147604                 bone marrow
# ERR4147605                 bone marrow
# ERR4147606                 bone marrow
# ERR4147607                 bone marrow
# ERR4147608                 bone marrow
# ERR4147609                 bone marrow
# ERR4147610                 bone marrow
# ERR4147611                 bone marrow
#
#                 Factor Value Ontology Term[organism part]  \
# ERR4147602  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147603  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147604  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147605  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147606  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147607  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147608  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147609  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147610  http://purl.obolibrary.org/obo/UBERON_0002371
# ERR4147611  http://purl.obolibrary.org/obo/UBERON_0002371
#
#            Factor Value[sampling site]  \
# ERR4147602                         hip
# ERR4147603                         hip
# ERR4147604                         hip
# ERR4147605                         hip
# ERR4147606                         hip
# ERR4147607                         hip
# ERR4147608                         hip
# ERR4147609                         hip
# ERR4147610                         hip
# ERR4147611                         hip
#
#                 Factor Value Ontology Term[sampling site]  \
# ERR4147602  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147603  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147604  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147605  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147606  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147607  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147608  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147609  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147610  http://purl.obolibrary.org/obo/UBERON_0001464
# ERR4147611  http://purl.obolibrary.org/obo/UBERON_0001464
#
#            Factor Value[inferred cell type - authors labels]  \
# ERR4147602                                               NaN
# ERR4147603                                               NaN
# ERR4147604                         erythroid progenitor cell
# ERR4147605                                               NaN
# ERR4147606                                               NaN
# ERR4147607                                               NaN
# ERR4147608                                               NaN
# ERR4147609                                               NaN
# ERR4147610                                               NaN
# ERR4147611                      cycling committed progenitor
#
#            Factor Value Ontology Term[inferred cell type - authors labels]  \
# ERR4147602                                                NaN
# ERR4147603                                                NaN
# ERR4147604          http://purl.obolibrary.org/obo/CL_0000038
# ERR4147605                                                NaN
# ERR4147606                                                NaN
# ERR4147607                                                NaN
# ERR4147608                                                NaN
# ERR4147609                                                NaN
# ERR4147610                                                NaN
# ERR4147611                                                NaN
#
#             Factor Value[inferred cell type - ontology labels]  \
# ERR4147602                                                NaN
# ERR4147603                                                NaN
# ERR4147604                          erythroid progenitor cell
# ERR4147605                                                NaN
# ERR4147606                                                NaN
# ERR4147607                                                NaN
# ERR4147608                                                NaN
# ERR4147609                                                NaN
# ERR4147610                                                NaN
# ERR4147611                                    progenitor cell
#
#            Factor Value Ontology Term[inferred cell type - ontology labels]  \
# ERR4147602                                                NaN
# ERR4147603                                                NaN
# ERR4147604          http://purl.obolibrary.org/obo/CL_0000038
# ERR4147605                                                NaN
# ERR4147606                                                NaN
# ERR4147607                                                NaN
# ERR4147608                                                NaN
# ERR4147609                                                NaN
# ERR4147610                                                NaN
# ERR4147611          http://purl.obolibrary.org/obo/CL_0011026
#
#             n_genes
# ERR4147602     2191
# ERR4147603     1810
# ERR4147604     3929
# ERR4147605     5115
# ERR4147606     2137
# ERR4147607     2561
# ERR4147608     2890
# ERR4147609     2271
# ERR4147610     3252
# ERR4147611     5067
#
# [10 rows x 33 columns]

# %% [markdown]
# Next, we need to load pathway annotation information.
#
# In the next cell we use the MIPath `parse_gmt` function to parse a `.gmt` file downloaded from **MSigDB**, and translate it from HUGO gene names to Ensembl gene IDs using a file created using [BioMart](https://www.ensembl.org/info/data/biomart/index.html).
#
# For Reactome, MIPath includes a function `get_reactome` that automatically downloads the latest version of the database and parses it. Reactome is already annotated using Ensembl gene IDs.

# %%
kegg = mipath.parse_gmt(gmt_path = './data/c2.cp.kegg.v7.5.1.symbols.gmt', gene_id_dict_path = './data/name2ensembl_human.txt')

reactome = mipath.get_reactome(organism = 'HSA', gene_anot = 'Ensembl')

# %% [markdown]
# We finally have everything we need to run the analysis. There are 2 steps in the MIPath pipeline.
#
# The first step is to decompose the data into different modules for each pathway in the dataset. We use the `decompose_pathways` function, inputting both the gene expression data, and the pathway annotation. This is the most computationally expensive part of the analysis.

# %%
decomposed_df = mipath.decompose_pathways(data = data, gene_sets_df = kegg)
# Out:
# Performing pathway decomposition
# (1/186) --- KEGG_N_GLYCAN_BIOSYNTHESIS --- 46 genes
# Computed 25 NN in 7.1 s
# SNN scores in 0.1 s
# Found 23 partitions in 0.3 s
#
# (2/186) --- KEGG_OTHER_GLYCAN_DEGRADATION --- 24 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 28 partitions in 0.2 s
#
# (3/186) --- KEGG_O_GLYCAN_BIOSYNTHESIS --- 30 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 29 partitions in 0.1 s
#
# (4/186) --- KEGG_GLYCOSAMINOGLYCAN_DEGRADATION --- 20 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 30 partitions in 0.1 s
#
# (5/186) --- KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_KERATAN_SULFATE --- 14 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 28 partitions in 0.1 s
#
# (6/186) --- KEGG_GLYCEROLIPID_METABOLISM --- 57 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 28 partitions in 0.3 s
#
# (7/186) --- KEGG_GLYCOSYLPHOSPHATIDYLINOSITOL_GPI_ANCHOR_BIOSYNTHESIS --- 25 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.3 s
#
# (8/186) --- KEGG_GLYCEROPHOSPHOLIPID_METABOLISM --- 95 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 24 partitions in 0.2 s
#
# (9/186) --- KEGG_ETHER_LIPID_METABOLISM --- 34 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 29 partitions in 0.1 s
#
# (10/186) --- KEGG_ARACHIDONIC_ACID_METABOLISM --- 62 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 23 partitions in 0.2 s
#
# (11/186) --- KEGG_LINOLEIC_ACID_METABOLISM --- 29 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 34 partitions in 0.2 s
#
# (12/186) --- KEGG_ALPHA_LINOLENIC_ACID_METABOLISM --- 19 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 35 partitions in 0.1 s
#
# (13/186) --- KEGG_SPHINGOLIPID_METABOLISM --- 48 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.2 s
#
# (14/186) --- KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_LACTO_AND_NEOLACTO_SERIES --- 27 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 32 partitions in 0.1 s
#
# (15/186) --- KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_GLOBO_SERIES --- 13 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 28 partitions in 0.1 s
#
# (16/186) --- KEGG_GLYCOSPHINGOLIPID_BIOSYNTHESIS_GANGLIO_SERIES --- 18 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 30 partitions in 0.2 s
#
# (17/186) --- KEGG_RIBOFLAVIN_METABOLISM --- 15 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 32 partitions in 0.1 s
#
# (18/186) --- KEGG_NICOTINATE_AND_NICOTINAMIDE_METABOLISM --- 23 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 21 partitions in 0.1 s
#
# (19/186) --- KEGG_PANTOTHENATE_AND_COA_BIOSYNTHESIS --- 16 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 30 partitions in 0.2 s
#
# (20/186) --- KEGG_AMINOACYL_TRNA_BIOSYNTHESIS --- 53 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 23 partitions in 0.3 s
#
# (21/186) --- KEGG_BASAL_TRANSCRIPTION_FACTORS --- 44 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 24 partitions in 0.2 s
#
# (22/186) --- KEGG_NON_HOMOLOGOUS_END_JOINING --- 12 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 27 partitions in 0.2 s
#
# (23/186) --- KEGG_SNARE_INTERACTIONS_IN_VESICULAR_TRANSPORT --- 37 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 30 partitions in 0.3 s
#
# (24/186) --- KEGG_LYSOSOME --- 137 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 10 partitions in 0.2 s
#
# (25/186) --- KEGG_CARDIAC_MUSCLE_CONTRACTION --- 81 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 9 partitions in 0.3 s
#
# (26/186) --- KEGG_RENIN_ANGIOTENSIN_SYSTEM --- 16 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 27 partitions in 0.2 s
#
# (27/186) --- KEGG_CIRCADIAN_RHYTHM_MAMMAL --- 12 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 34 partitions in 0.1 s
#
# (28/186) --- KEGG_TASTE_TRANSDUCTION --- 78 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 24 partitions in 0.1 s
#
# (29/186) --- KEGG_PROXIMAL_TUBULE_BICARBONATE_RECLAMATION --- 24 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 30 partitions in 0.1 s
#
# (30/186) --- KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION --- 67 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 9 partitions in 0.2 s
#
# (31/186) --- KEGG_SYSTEMIC_LUPUS_ERYTHEMATOSUS --- 237 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.2 s
#
# (32/186) --- KEGG_PRIMARY_IMMUNODEFICIENCY --- 49 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 21 partitions in 0.2 s
#
# (33/186) --- KEGG_HYPERTROPHIC_CARDIOMYOPATHY_HCM --- 91 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 16 partitions in 0.3 s
#
# (34/186) --- KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC --- 76 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 18 partitions in 0.2 s
#
# (35/186) --- KEGG_DILATED_CARDIOMYOPATHY --- 100 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 16 partitions in 0.3 s
#
# (36/186) --- KEGG_GLYCOLYSIS_GLUCONEOGENESIS --- 65 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 11 partitions in 0.4 s
#
# (37/186) --- KEGG_CITRATE_CYCLE_TCA_CYCLE --- 31 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 22 partitions in 0.3 s
#
# (38/186) --- KEGG_PENTOSE_PHOSPHATE_PATHWAY --- 26 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 20 partitions in 0.3 s
#
# (39/186) --- KEGG_PENTOSE_AND_GLUCURONATE_INTERCONVERSIONS --- 29 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 30 partitions in 0.2 s
#
# (40/186) --- KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM --- 34 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.2 s
#
# (41/186) --- KEGG_GALACTOSE_METABOLISM --- 27 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.2 s
#
# (42/186) --- KEGG_ASCORBATE_AND_ALDARATE_METABOLISM --- 26 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 36 partitions in 0.2 s
#
# (43/186) --- KEGG_FATTY_ACID_METABOLISM --- 41 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 26 partitions in 0.3 s
#
# (44/186) --- KEGG_STEROID_BIOSYNTHESIS --- 18 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 27 partitions in 0.1 s
#
# (45/186) --- KEGG_PRIMARY_BILE_ACID_BIOSYNTHESIS --- 16 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 29 partitions in 0.1 s
#
# (46/186) --- KEGG_STEROID_HORMONE_BIOSYNTHESIS --- 67 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 28 partitions in 0.1 s
#
# (47/186) --- KEGG_OXIDATIVE_PHOSPHORYLATION --- 155 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.3 s
# Found 8 partitions in 0.1 s
#
# (48/186) --- KEGG_PURINE_METABOLISM --- 164 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 9 partitions in 0.4 s
#
# (49/186) --- KEGG_PYRIMIDINE_METABOLISM --- 99 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.2 s
# Found 14 partitions in 0.2 s
#
# (50/186) --- KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM --- 32 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 28 partitions in 0.4 s
#
# (51/186) --- KEGG_GLYCINE_SERINE_AND_THREONINE_METABOLISM --- 31 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 28 partitions in 0.2 s
#
# (52/186) --- KEGG_CYSTEINE_AND_METHIONINE_METABOLISM --- 35 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 21 partitions in 0.3 s
#
# (53/186) --- KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION --- 45 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 22 partitions in 0.2 s
#
# (54/186) --- KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_BIOSYNTHESIS --- 21 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 26 partitions in 0.1 s
#
# (55/186) --- KEGG_LYSINE_DEGRADATION --- 49 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 24 partitions in 0.2 s
#
# (56/186) --- KEGG_ARGININE_AND_PROLINE_METABOLISM --- 55 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 23 partitions in 0.2 s
#
# (57/186) --- KEGG_HISTIDINE_METABOLISM --- 29 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 28 partitions in 0.2 s
#
# (58/186) --- KEGG_TYROSINE_METABOLISM --- 43 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.3 s
#
# (59/186) --- KEGG_PHENYLALANINE_METABOLISM --- 18 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 26 partitions in 0.1 s
#
# (60/186) --- KEGG_TRYPTOPHAN_METABOLISM --- 40 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 27 partitions in 0.1 s
#
# (61/186) --- KEGG_BETA_ALANINE_METABOLISM --- 21 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 28 partitions in 0.4 s
#
# (62/186) --- KEGG_TAURINE_AND_HYPOTAURINE_METABOLISM --- 10 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 54 partitions in 0.1 s
#
# (63/186) --- KEGG_SELENOAMINO_ACID_METABOLISM --- 25 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 28 partitions in 0.2 s
#
# (64/186) --- KEGG_GLUTATHIONE_METABOLISM --- 52 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 17 partitions in 0.4 s
#
# (65/186) --- KEGG_STARCH_AND_SUCROSE_METABOLISM --- 56 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 30 partitions in 0.2 s
#
# (66/186) --- KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM --- 45 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 30 partitions in 0.3 s
#
# (67/186) --- KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_CHONDROITIN_SULFATE --- 22 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 25 partitions in 0.2 s
#
# (68/186) --- KEGG_GLYCOSAMINOGLYCAN_BIOSYNTHESIS_HEPARAN_SULFATE --- 26 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 25 partitions in 0.1 s
#
# (69/186) --- KEGG_INOSITOL_PHOSPHATE_METABOLISM --- 56 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 22 partitions in 0.2 s
#
# (70/186) --- KEGG_PYRUVATE_METABOLISM --- 43 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 19 partitions in 0.3 s
#
# (71/186) --- KEGG_GLYOXYLATE_AND_DICARBOXYLATE_METABOLISM --- 15 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 27 partitions in 0.2 s
#
# (72/186) --- KEGG_PROPANOATE_METABOLISM --- 34 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 22 partitions in 0.2 s
#
# (73/186) --- KEGG_BUTANOATE_METABOLISM --- 34 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 27 partitions in 0.2 s
#
# (74/186) --- KEGG_ONE_CARBON_POOL_BY_FOLATE --- 19 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 21 partitions in 0.2 s
#
# (75/186) --- KEGG_FOLATE_BIOSYNTHESIS --- 10 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 42 partitions in 0.1 s
#
# (76/186) --- KEGG_RETINOL_METABOLISM --- 67 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 27 partitions in 0.1 s
#
# (77/186) --- KEGG_PORPHYRIN_AND_CHLOROPHYLL_METABOLISM --- 44 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 28 partitions in 0.2 s
#
# (78/186) --- KEGG_TERPENOID_BACKBONE_BIOSYNTHESIS --- 14 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 30 partitions in 0.2 s
#
# (79/186) --- KEGG_LIMONENE_AND_PINENE_DEGRADATION --- 9 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 28 partitions in 0.1 s
#
# (80/186) --- KEGG_NITROGEN_METABOLISM --- 23 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 27 partitions in 0.2 s
#
# (81/186) --- KEGG_SULFUR_METABOLISM --- 12 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 35 partitions in 0.2 s
#
# (82/186) --- KEGG_METABOLISM_OF_XENOBIOTICS_BY_CYTOCHROME_P450 --- 72 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.3 s
#
# (83/186) --- KEGG_DRUG_METABOLISM_CYTOCHROME_P450 --- 79 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 27 partitions in 0.3 s
#
# (84/186) --- KEGG_DRUG_METABOLISM_OTHER_ENZYMES --- 54 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 30 partitions in 0.2 s
#
# (85/186) --- KEGG_BIOSYNTHESIS_OF_UNSATURATED_FATTY_ACIDS --- 22 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 27 partitions in 0.2 s
#
# (86/186) --- KEGG_ABC_TRANSPORTERS --- 60 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 29 partitions in 0.2 s
#
# (87/186) --- KEGG_RIBOSOME --- 104 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 12 partitions in 0.2 s
#
# (88/186) --- KEGG_RNA_DEGRADATION --- 79 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 11 partitions in 0.2 s
#
# (89/186) --- KEGG_RNA_POLYMERASE --- 30 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 23 partitions in 0.3 s
#
# (90/186) --- KEGG_DNA_REPLICATION --- 35 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 24 partitions in 0.2 s
#
# (91/186) --- KEGG_SPLICEOSOME --- 160 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 7 partitions in 0.2 s
#
# (92/186) --- KEGG_PROTEASOME --- 64 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.2 s
# Found 8 partitions in 0.4 s
#
# (93/186) --- KEGG_PROTEIN_EXPORT --- 23 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.4 s
#
# (94/186) --- KEGG_PPAR_SIGNALING_PATHWAY --- 74 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 23 partitions in 0.3 s
#
# (95/186) --- KEGG_BASE_EXCISION_REPAIR --- 34 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 20 partitions in 0.3 s
#
# (96/186) --- KEGG_NUCLEOTIDE_EXCISION_REPAIR --- 52 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 24 partitions in 0.3 s
#
# (97/186) --- KEGG_MISMATCH_REPAIR --- 23 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 24 partitions in 0.2 s
#
# (98/186) --- KEGG_HOMOLOGOUS_RECOMBINATION --- 28 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.2 s
#
# (99/186) --- KEGG_MAPK_SIGNALING_PATHWAY --- 307 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.2 s
# Found 10 partitions in 0.1 s
#
# (100/186) --- KEGG_ERBB_SIGNALING_PATHWAY --- 88 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 14 partitions in 0.3 s
#
# (101/186) --- KEGG_CALCIUM_SIGNALING_PATHWAY --- 181 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 11 partitions in 0.3 s
#
# (102/186) --- KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION --- 303 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 17 partitions in 0.2 s
#
# (103/186) --- KEGG_CHEMOKINE_SIGNALING_PATHWAY --- 213 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 11 partitions in 0.2 s
#
# (104/186) --- KEGG_PHOSPHATIDYLINOSITOL_SIGNALING_SYSTEM --- 80 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 13 partitions in 0.4 s
#
# (105/186) --- KEGG_NEUROACTIVE_LIGAND_RECEPTOR_INTERACTION --- 288 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.2 s
# Found 19 partitions in 0.2 s
#
# (106/186) --- KEGG_CELL_CYCLE --- 129 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 8 partitions in 0.3 s
#
# (107/186) --- KEGG_OOCYTE_MEIOSIS --- 118 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 9 partitions in 0.2 s
#
# (108/186) --- KEGG_P53_SIGNALING_PATHWAY --- 69 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 18 partitions in 0.2 s
#
# (109/186) --- KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS --- 137 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.4 s
# Found 9 partitions in 0.2 s
#
# (110/186) --- KEGG_REGULATION_OF_AUTOPHAGY --- 34 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 26 partitions in 0.3 s
#
# (111/186) --- KEGG_ENDOCYTOSIS --- 243 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.2 s
# Found 12 partitions in 0.2 s
#
# (112/186) --- KEGG_PEROXISOME --- 83 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.3 s
#
# (113/186) --- KEGG_MTOR_SIGNALING_PATHWAY --- 53 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 18 partitions in 0.3 s
#
# (114/186) --- KEGG_APOPTOSIS --- 97 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.3 s
#
# (115/186) --- KEGG_VASCULAR_SMOOTH_MUSCLE_CONTRACTION --- 119 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 12 partitions in 0.3 s
#
# (116/186) --- KEGG_WNT_SIGNALING_PATHWAY --- 164 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.2 s
# Found 9 partitions in 0.3 s
#
# (117/186) --- KEGG_DORSO_VENTRAL_AXIS_FORMATION --- 31 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 27 partitions in 0.2 s
#
# (118/186) --- KEGG_NOTCH_SIGNALING_PATHWAY --- 56 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.2 s
#
# (119/186) --- KEGG_HEDGEHOG_SIGNALING_PATHWAY --- 59 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 26 partitions in 0.1 s
#
# (120/186) --- KEGG_TGF_BETA_SIGNALING_PATHWAY --- 94 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 16 partitions in 0.3 s
#
# (121/186) --- KEGG_AXON_GUIDANCE --- 133 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 10 partitions in 0.3 s
#
# (122/186) --- KEGG_VEGF_SIGNALING_PATHWAY --- 79 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 18 partitions in 0.3 s
#
# (123/186) --- KEGG_FOCAL_ADHESION --- 217 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 9 partitions in 0.2 s
#
# (124/186) --- KEGG_ECM_RECEPTOR_INTERACTION --- 105 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 24 partitions in 0.2 s
#
# (125/186) --- KEGG_CELL_ADHESION_MOLECULES_CAMS --- 250 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 19 partitions in 0.2 s
#
# (126/186) --- KEGG_ADHERENS_JUNCTION --- 80 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 9 partitions in 0.3 s
#
# (127/186) --- KEGG_TIGHT_JUNCTION --- 149 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 9 partitions in 0.2 s
#
# (128/186) --- KEGG_GAP_JUNCTION --- 103 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.2 s
#
# (129/186) --- KEGG_COMPLEMENT_AND_COAGULATION_CASCADES --- 91 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 28 partitions in 0.2 s
#
# (130/186) --- KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION --- 521 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 16 partitions in 0.2 s
#
# (131/186) --- KEGG_TOLL_LIKE_RECEPTOR_SIGNALING_PATHWAY --- 115 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 12 partitions in 0.3 s
#
# (132/186) --- KEGG_NOD_LIKE_RECEPTOR_SIGNALING_PATHWAY --- 72 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 14 partitions in 0.3 s
#
# (133/186) --- KEGG_RIG_I_LIKE_RECEPTOR_SIGNALING_PATHWAY --- 80 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 23 partitions in 0.3 s
#
# (134/186) --- KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY --- 63 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 20 partitions in 0.2 s
#
# (135/186) --- KEGG_JAK_STAT_SIGNALING_PATHWAY --- 159 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 14 partitions in 0.2 s
#
# (136/186) --- KEGG_HEMATOPOIETIC_CELL_LINEAGE --- 103 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 17 partitions in 0.2 s
#
# (137/186) --- KEGG_NATURAL_KILLER_CELL_MEDIATED_CYTOTOXICITY --- 453 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.2 s
# Found 13 partitions in 0.2 s
#
# (138/186) --- KEGG_T_CELL_RECEPTOR_SIGNALING_PATHWAY --- 121 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 8 partitions in 0.3 s
#
# (139/186) --- KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY --- 82 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 9 partitions in 0.2 s
#
# (140/186) --- KEGG_FC_EPSILON_RI_SIGNALING_PATHWAY --- 89 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.4 s
#
# (141/186) --- KEGG_FC_GAMMA_R_MEDIATED_PHAGOCYTOSIS --- 100 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 9 partitions in 0.3 s
#
# (142/186) --- KEGG_LEUKOCYTE_TRANSENDOTHELIAL_MIGRATION --- 121 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.2 s
# Found 11 partitions in 0.2 s
#
# (143/186) --- KEGG_INTESTINAL_IMMUNE_NETWORK_FOR_IGA_PRODUCTION --- 114 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 17 partitions in 0.1 s
#
# (144/186) --- KEGG_LONG_TERM_POTENTIATION --- 73 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 14 partitions in 0.4 s
#
# (145/186) --- KEGG_NEUROTROPHIN_SIGNALING_PATHWAY --- 130 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.3 s
# Found 7 partitions in 0.3 s
#
# (146/186) --- KEGG_LONG_TERM_DEPRESSION --- 73 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 17 partitions in 0.3 s
#
# (147/186) --- KEGG_OLFACTORY_TRANSDUCTION --- 515 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 17 partitions in 0.2 s
#
# (148/186) --- KEGG_REGULATION_OF_ACTIN_CYTOSKELETON --- 219 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.4 s
# Found 8 partitions in 0.2 s
#
# (149/186) --- KEGG_INSULIN_SIGNALING_PATHWAY --- 154 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 8 partitions in 0.3 s
#
# (150/186) --- KEGG_GNRH_SIGNALING_PATHWAY --- 105 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 13 partitions in 0.4 s
#
# (151/186) --- KEGG_PROGESTERONE_MEDIATED_OOCYTE_MATURATION --- 89 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 13 partitions in 0.3 s
#
# (152/186) --- KEGG_MELANOGENESIS --- 106 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 14 partitions in 0.2 s
#
# (153/186) --- KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY --- 84 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.2 s
# Found 24 partitions in 0.3 s
#
# (154/186) --- KEGG_TYPE_II_DIABETES_MELLITUS --- 56 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 28 partitions in 0.1 s
#
# (155/186) --- KEGG_TYPE_I_DIABETES_MELLITUS --- 159 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.1 s
# Found 19 partitions in 0.2 s
#
# (156/186) --- KEGG_MATURITY_ONSET_DIABETES_OF_THE_YOUNG --- 25 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 34 partitions in 0.1 s
#
# (157/186) --- KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION --- 41 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 27 partitions in 0.2 s
#
# (158/186) --- KEGG_VASOPRESSIN_REGULATED_WATER_REABSORPTION --- 46 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 17 partitions in 0.4 s
#
# (159/186) --- KEGG_ALZHEIMERS_DISEASE --- 191 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 7 partitions in 0.2 s
#
# (160/186) --- KEGG_PARKINSONS_DISEASE --- 146 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 8 partitions in 0.1 s
#
# (161/186) --- KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS --- 64 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 18 partitions in 0.4 s
#
# (162/186) --- KEGG_HUNTINGTONS_DISEASE --- 202 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 6 partitions in 0.2 s
#
# (163/186) --- KEGG_PRION_DISEASES --- 40 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.2 s
#
# (164/186) --- KEGG_VIBRIO_CHOLERAE_INFECTION --- 65 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 11 partitions in 0.3 s
#
# (165/186) --- KEGG_EPITHELIAL_CELL_SIGNALING_IN_HELICOBACTER_PYLORI_INFECTION --- 77 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 16 partitions in 0.2 s
#
# (166/186) --- KEGG_LEISHMANIA_INFECTION --- 147 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 16 partitions in 0.2 s
#
# (167/186) --- KEGG_PATHWAYS_IN_CANCER --- 337 genes
# Computed 25 NN in 0.2 s
# SNN scores in 0.3 s
# Found 10 partitions in 0.2 s
#
# (168/186) --- KEGG_COLORECTAL_CANCER --- 62 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 11 partitions in 0.2 s
#
# (169/186) --- KEGG_RENAL_CELL_CARCINOMA --- 71 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.4 s
#
# (170/186) --- KEGG_PANCREATIC_CANCER --- 71 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.3 s
#
# (171/186) --- KEGG_ENDOMETRIAL_CANCER --- 54 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 23 partitions in 0.3 s
#
# (172/186) --- KEGG_GLIOMA --- 68 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 12 partitions in 0.3 s
#
# (173/186) --- KEGG_PROSTATE_CANCER --- 92 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 11 partitions in 0.3 s
#
# (174/186) --- KEGG_THYROID_CANCER --- 34 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 22 partitions in 0.2 s
#
# (175/186) --- KEGG_BASAL_CELL_CARCINOMA --- 57 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.0 s
# Found 27 partitions in 0.1 s
#
# (176/186) --- KEGG_MELANOMA --- 75 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 27 partitions in 0.3 s
#
# (177/186) --- KEGG_BLADDER_CANCER --- 43 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 25 partitions in 0.2 s
#
# (178/186) --- KEGG_CHRONIC_MYELOID_LEUKEMIA --- 75 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 13 partitions in 0.3 s
#
# (179/186) --- KEGG_ACUTE_MYELOID_LEUKEMIA --- 58 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 20 partitions in 0.2 s
#
# (180/186) --- KEGG_SMALL_CELL_LUNG_CANCER --- 91 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 16 partitions in 0.3 s
#
# (181/186) --- KEGG_NON_SMALL_CELL_LUNG_CANCER --- 61 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 18 partitions in 0.2 s
#
# (182/186) --- KEGG_ASTHMA --- 102 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 20 partitions in 0.2 s
#
# (183/186) --- KEGG_AUTOIMMUNE_THYROID_DISEASE --- 155 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 19 partitions in 0.2 s
#
# (184/186) --- KEGG_ALLOGRAFT_REJECTION --- 146 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 20 partitions in 0.2 s
#
# (185/186) --- KEGG_GRAFT_VERSUS_HOST_DISEASE --- 302 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 19 partitions in 0.3 s
#
# (186/186) --- KEGG_VIRAL_MYOCARDITIS --- 173 genes
# Computed 25 NN in 0.1 s
# SNN scores in 0.1 s
# Found 15 partitions in 0.2 s

# %% [markdown]
# Now we are ready to see how well these modules represent phenotype information, using the `score_factors` function.
#
# We input the dataframe obtained in the previous step, the one containing the phenotype information, and a list of things to score, that must match exactly column names from the phenotype dataframe.

# %%
to_score = ['Factor Value[inferred cell type - authors labels]', 'Factor Value[sampling site]']

result = mipath.score_factors(decomposed_df, metadata, to_score)
# Out:
# Scoring Factor Value[inferred cell type - authors labels]
# Scoring Factor Value[sampling site]

# %% [markdown]
# And we can now display the final results

# %%
result.sort_values('Factor Value[inferred cell type - authors labels]', ascending=False)
# Out:
#                                              Factor Value[inferred cell type - authors labels]  \
# KEGG_HEMATOPOIETIC_CELL_LINEAGE                                                       0.404919
# KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION                                           0.330273
# KEGG_LYSOSOME                                                                         0.313702
# KEGG_CELL_ADHESION_MOLECULES_CAMS                                                     0.303012
# KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION                                              0.300463
# ...                                                                                        ...
# KEGG_LINOLEIC_ACID_METABOLISM                                                         0.054820
# KEGG_OTHER_GLYCAN_DEGRADATION                                                         0.053092
# KEGG_REGULATION_OF_AUTOPHAGY                                                          0.050851
# KEGG_CIRCADIAN_RHYTHM_MAMMAL                                                          0.044396
# KEGG_TAURINE_AND_HYPOTAURINE_METABOLISM                                               0.031721
#
#                                              Factor Value[sampling site]
# KEGG_HEMATOPOIETIC_CELL_LINEAGE                                 0.027009
# KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION                     0.011363
# KEGG_LYSOSOME                                                   0.014283
# KEGG_CELL_ADHESION_MOLECULES_CAMS                               0.062967
# KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION                        0.074172
# ...                                                                  ...
# KEGG_LINOLEIC_ACID_METABOLISM                                   0.002627
# KEGG_OTHER_GLYCAN_DEGRADATION                                   0.005065
# KEGG_REGULATION_OF_AUTOPHAGY                                    0.003167
# KEGG_CIRCADIAN_RHYTHM_MAMMAL                                    0.004115
# KEGG_TAURINE_AND_HYPOTAURINE_METABOLISM                         0.001274
#
# [186 rows x 2 columns]
